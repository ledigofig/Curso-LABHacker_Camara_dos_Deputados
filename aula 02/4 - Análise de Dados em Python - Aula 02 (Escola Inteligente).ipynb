# %% [markdown]
# # analise de dados do Escola Inteligente
# - dados inep disponibilizado por api

# %% [markdown]
# A fonte de dados é :http://educacao.dadosabertosbr.com/

# %%
#importando as bibliotecas 
import pandas as pd
import requests

#Url da api
url_api = 'http://educacao.dadosabertosbr.com/api/escolas/buscaavancada?situacaoFuncionamento=1&energiaInexistente=on&aguaInexistente=on&esgotoInexistente=on&cozinha=on'

#RequisitANDO api COM REQUESTS
resposta =requests.get(url_api)


#criando dataframe
df = pd.DataFrame(resposta.json()[1])
df.head()
# Out:
#    anoCenso       cod                        nome  codCidade  \
# 0      2013  41036026  BAIRRO DOS MENDES E R M EF    4104402
# 1      2013  15008258           E M E F AGUA AZUL    1504802
# 2      2013  15534340            E M E F AGUA BOA    1505650
# 3      2013  15525821            E M E F AMAZONIA    1505064
# 4      2013  15022790      E M E F AMELIA HOLANDA    1500305
#
#               cidade estado regiao  situacaoFuncionamento  \
# 0   CANDIDO DE ABREU     PR    Sul                      1
# 1       MONTE ALEGRE     PA  Norte                      1
# 2             PLACAS     PA  Norte                      1
# 3  NOVO REPARTIMENTO     PA  Norte                      1
# 4               AFUA     PA  Norte                      1
#
#    dependenciaAdministrativa  idebAI  idebAF  enemMediaGeral  \
# 0                          3     0.0     0.0             0.0
# 1                          3     0.0     0.0             0.0
# ...

# %%
df.tail()
# Out:
#     anoCenso       cod                                  nome  codCidade  \
# 95      2013  15103692               E M E F PRINCESA ISABEL    1506195
# 96      2013  15227499   E M E F PROF JONATHAS PONTES ATHIAS    1505106
# 97      2013  15556956  E M E F PROFESSORA ALDALETE FERREIRA    1500305
# 98      2013  15536521      E M E F RAIMUNDO DE SOUZA SANTOS    1504703
# 99      2013  15023664             E M E F RAIMUNDO NOGUEIRA    1500305
#
#        cidade estado regiao  situacaoFuncionamento  dependenciaAdministrativa  \
# 95  RUROPOLIS     PA  Norte                      1                          3
# 96     OBIDOS     PA  Norte                      1                          3
# 97       AFUA     PA  Norte                      1                          3
# 98       MOJU     PA  Norte                      1                          3
# 99       AFUA     PA  Norte                      1                          3
#
#     idebAI  idebAF  enemMediaGeral situacaoFuncionamentoTxt  \
# ...

# %%
df['estado'].value_counts()
# Out:
# PA    99
# PR     1
# Name: estado, dtype: int64

# %%
df['dependenciaAdministrativaTxt'].value_counts()
# Out:
# Municipal    100
# Name: dependenciaAdministrativaTxt, dtype: int64
